# %%
c(4, 5, 6, 8) + c(3,6, 9, 12)  #Addition
c(3, 7, 8, 5) + c(2, 6)
# Out:
# [1]  7 11 15 20
# [1]  5 13 10 11

# %%
c(3, 7, 8, 5) + c(2, 6, 8)  #Addition Error
# Out:
# Warning message in c(3, 7, 8, 5) + c(2, 6, 8):
# “longer object length is not a multiple of shorter object length”
# [1]  5 13 16  7

# %%
c(1, 3, 5, 7) - c(2, -4, -5, 8)   #Substraction
c(3, 6, -1, -5) - c(2, -5)
# Out:
# [1] -1  7 10 -1
# [1]  1 11 -3  0

# %%
c(3, -5, -7, 9) - c(2, -5, 8)   #Substraction Error
# Out:
# Warning message in c(3, -5, -7, 9) - c(2, -5, 8):
# “longer object length is not a multiple of shorter object length”
# [1]   1   0 -15   7

# %%
c(2, 3, 4, 5) * c(4, 5, 6, 7)    #Multiplication
c(5, 7, 9, 11) * c(4, 8)
# Out:
# [1]  8 15 24 35
# [1] 20 56 36 88

# %%
c(3, 5, 4, 1) * c(3, 5, 7)    #Multiplication Error
# Out:
# Warning message in c(3, 5, 4, 1) * c(3, 5, 7):
# “longer object length is not a multiple of shorter object length”
# [1]  9 25 28  3

# %%
c(4, 8, 12, 16) / c(2, 4, 6, 8)   #Division
c(12, 16, 20, 24) / c(4, 6)
# Out:
# [1] 2 2 2 2
# [1] 3.000000 2.666667 5.000000 4.000000

# %%
c(3, 6, 9, 12) / c(2, 3, 4)   #Division Error
# Out:
# Warning message in c(3, 6, 9, 12)/c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1] 1.50 2.00 2.25 6.00

# %%
x = 20
x
# Out:
# [1] 20

# %%
x <- 20
x
# Out:
# [1] 20

# %%
x = apple
# Out:
# Error: object 'apple' not found
# Traceback:

# %%
x = "apple"
x
# Out:
# [1] "apple"

# %%
x = 20
is.numeric(x)
is.character(x)

y = "apple"
is.numeric(y)
is.numeric(x)
# Out:
# [1] TRUE
# [1] FALSE
# [1] FALSE
# [1] TRUE

# %%
x = 20
is.numeric(x)
y=as.character(x)
is.numeric(y)
is.character(y)
# Out:
# [1] TRUE
# [1] FALSE
# [1] TRUE

# %%
y = "apple"
is.character(y)
is.numeric(y)
z = as.numeric(y)
is.character(z)
is.numeric(z)
z
# Out:
# [1] TRUE
# [1] FALSE
# Warning message:
# “NAs introduced by coercion”
# [1] FALSE
# [1] TRUE
# [1] NA

# %%
y <- 30
Y
# Out:
# Error: object 'Y' not found
# Traceback:

# %%
Y <- 20
y
# Out:
# [1] 30

# %%
y = 1, 2, 3, 4, 5
# Out:
# Error in parse(text = input): <text>:1:6: unexpected ','
# 1: y = 1,
#          ^
# Traceback:

# %%
y = (1, 2, 3, 4, 5)
# Out:
# Error in parse(text = input): <text>:1:7: unexpected ','
# 1: y = (1,
#           ^
# Traceback:

# %%
y = c(1, 2, 3, 4, 5)
y
# Out:
# [1] 1 2 3 4 5

# %%
x = 20
x
mode(x)
# Out:
# [1] 20
# [1] "numeric"

# %%
y = "apple"
y
mode(y)
# Out:
# [1] "apple"
# [1] "character"

# %%
x = 6
storage.mode(x)
y = TRUE
storage.mode(y)
z = "True"
storage.mode(z)
# Out:
# [1] "double"
# [1] "logical"
# [1] "character"

# %%
3/0
5 + Inf
x = 5+Inf
is.finite(x)
is.infinite(x)
# Out:
# [1] Inf
# [1] Inf
# [1] FALSE
# [1] TRUE

# %%
2+3
2*3
2-3
3/2
2*3-5/2+6
# Out:
# [1] 5
# [1] 6
# [1] -1
# [1] 1.5
# [1] 9.5

# %%
(3*5)/4
((2+4)*5)-7
# Out:
# [1] 3.75
# [1] 23

# %%
2+3
2     +     3
2     +3
# Out:
# [1] 5
# [1] 5
# [1] 5

# %%
c(2, 3, 5, 8) + 10
c(22, 33, 55, 88) - 10
c(3, 4, 6, 9) * 10
c(30, 40, 50, 80) / 10
# Out:
# [1] 12 13 15 18
# [1] 12 23 45 78
# [1] 30 40 60 90
# [1] 3 4 5 8
